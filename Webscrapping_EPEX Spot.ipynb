# %% [markdown]
# ## Importing Libraries

# %%
from bs4 import BeautifulSoup
from datetime import datetime,date, timedelta

import urllib.request
import requests
import lxml.html as lh
import pandas as pd
import numpy as np

# %% [markdown]
# ## Web Scraping from Epex Website

# %% [markdown]
# ### 1. Accessing the Web Page

# %%
def date_selection(x):
    url1 = 'https://www.epexspot.com/en/market-data?market_area=DE&trading_date='
    url2 = '&delivery_date=' + x
    url3 = '&underlying_year=&modality=Continuous&sub_modality=&product=60&data_mode=table&period='
    url = url1 + url2 + url3  
    return(url)

# %%
### NOTE: There is no data available for intraday continuous fot the next day i.e. tomorrow.

date_download = input("Enter today, yesterday or tomorrow: ")
# Out:
# Enter today, yesterday or tomorrow: today

# %%
if date_download == 'today':
    date_download1 = str(date.today())
elif date_download == 'yesterday':
    date_download1 = str(date.today() - timedelta(days = 1))
elif date_download == 'tomorrow':
    date_download1 = str(date.today() + timedelta(days= 1))
else:
    data_download

# %%
#url = 'https://www.epexspot.com/en/market-data?market_area=DE&trading_date=&delivery_date=2019-12-14&underlying_year=&modality=Continuous&sub_modality=&product=60&data_mode=table&period='

# %%
url = date_selection(date_download1)
print(url)
# Out:
# https://www.epexspot.com/en/market-data?market_area=DE&trading_date=&delivery_date=2020-01-05&underlying_year=&modality=Continuous&sub_modality=&product=60&data_mode=table&period=

# %%
#Each browser has a unique way of communicating with the website. 
#Headers tells the website which browser is being used and what your operating system is 
#Header obtained from www.whoishostingthis.com/tools/user-agent/

headers = {'User-Agent' : 'Chrome/78.0.3904.108 '}

# fetch the content from url

page = requests.get(url, timeout=5, headers = headers)

#To check your connection to the website and to check if the html content has been downloaded
#200 indicates good connection and proper download

print(page.status_code)
# Out:
# 200

# %% [markdown]
# ### 2. Retrieving the Data

# %%
#Parsing the HTML content

soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="Market Data | EPEX SPOT" name="title"/>
#   <link href="https://www.epexspot.com/en/market-data" rel="canonical"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <script>
#    function euCookieComplianceLoadScripts() {}
#   </script>
#   <style>
#    div#sliding-popup, div#sliding-popup .eu-cookie-withdraw-banner, .eu-cookie-withdraw-tab {background: #0779bf} div#sliding-popup.eu-cookie-withdraw-wrapper { background: transparent; } #sliding-popup h1, #sliding-popup h2, #sliding-popup h3, #sliding-popup p, .eu-cookie-compliance-more-button, .eu-cookie-compliance-secondary-button, .eu-cookie-withdraw-tab { color: #ffffff;} .eu-cookie-withdraw-tab { border-color: #ffffff;}
#   </style>
#   <link href="/themes/custom/epex/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <link href="https://www.epexspot.com/en/market-data" hreflang="en" rel="alternate"/>
#   <link href="/en/market-data" rel="revision"/>
#   <title>
#    Market Data | EPEX SPOT
#   </title>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-153290465-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         gtag('js', new Date());
#         gtag('config', 'UA-153290465-1', { 'anonymize_ip': true });
#   </script>
#   <!-- Favicon -->
#   <link href="/themes/custom/epex/images/favicons/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/themes/custom/epex/images/favicons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="/themes/custom/epex/images/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/themes/custom/epex/images/favicons/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/themes/custom/epex/images/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/themes/custom/epex/images/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/themes/custom/epex/images/favicons/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="/themes/custom/epex/images/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/themes/custom/epex/images/favicons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/themes/custom/epex/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/themes/custom/epex/images/favicons/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="/themes/custom/epex/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/themes/custom/epex/images/favicons/site.webmanifest" rel="manifest"/>
#   <link color="#FF6600" href="/themes/custom/epex/images/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
#   <link href="/themes/custom/epex/images/favicons/favicon.ico" rel="shortcut icon"/>
#   <meta content="#ffffff" name="msapplication-TileColor"/>
#   <meta content="/themes/custom/epex/images/favicons/mstile-144x144.png" name="msapplication-TileImage"/>
#   <meta content="/themes/custom/epex/images/favicons/browserconfig.xml" name="msapplication-config"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <link href="/core/modules/system/css/components/align.module.css?q3dd6r" media="all" rel="stylesheet">
#    <link href="/core/modules/system/css/components/fieldgroup.module.css?q3dd6r" media="all" rel="stylesheet">
#     <link href="/core/modules/system/css/components/container-inline.module.css?q3dd6r" media="all" rel="stylesheet">
#      <link href="/core/modules/system/css/components/clearfix.module.css?q3dd6r" media="all" rel="stylesheet">
#       <link href="/core/modules/system/css/components/details.module.css?q3dd6r" media="all" rel="stylesheet">
#        <link href="/core/modules/system/css/components/hidden.module.css?q3dd6r" media="all" rel="stylesheet">
#         <link href="/core/modules/system/css/components/item-list.module.css?q3dd6r" media="all" rel="stylesheet">
#          <link href="/core/modules/system/css/components/js.module.css?q3dd6r" media="all" rel="stylesheet">
#           <link href="/core/modules/system/css/components/nowrap.module.css?q3dd6r" media="all" rel="stylesheet">
#            <link href="/core/modules/system/css/components/position-container.module.css?q3dd6r" media="all" rel="stylesheet">
#             <link href="/core/modules/system/css/components/progress.module.css?q3dd6r" media="all" rel="stylesheet">
#              <link href="/core/modules/system/css/components/reset-appearance.module.css?q3dd6r" media="all" rel="stylesheet">
#               <link href="/core/modules/system/css/components/resize.module.css?q3dd6r" media="all" rel="stylesheet">
#                <link href="/core/modules/system/css/components/sticky-header.module.css?q3dd6r" media="all" rel="stylesheet">
#                 <link href="/core/modules/system/css/components/system-status-counter.css?q3dd6r" media="all" rel="stylesheet">
#                  <link href="/core/modules/system/css/components/system-status-report-counters.css?q3dd6r" media="all" rel="stylesheet"/>
#                  <link href="/core/modules/system/css/components/system-status-report-general-info.css?q3dd6r" media="all" rel="stylesheet"/>
#                  <link href="/core/modules/system/css/components/tablesort.module.css?q3dd6r" media="all" rel="stylesheet"/>
#                  <link href="/core/modules/system/css/components/tree-child.module.css?q3dd6r" media="all" rel="stylesheet"/>
#                  <link href="/modules/contrib/eu_cookie_compliance/css/eu_cookie_compliance.css?q3dd6r" media="all" rel="stylesheet"/>
#                  <link href="/themes/custom/epex/lib/material-design-iconic-font/dist/css/material-design-iconic-font.min.css?q3dd6r" media="all" rel="stylesheet"/>
#                  <link href="/themes/custom/epex/fonts/SS_gizmo/webfonts/ss-gizmo.css?q3dd6r" media="all" rel="stylesheet"/>
#                  <link href="/themes/custom/epex/css/main.min.css?q3dd6r" media="all" rel="stylesheet"/>
#                  <!--[if lte IE 8]>
# <script src="/core/assets/vendor/html5shiv/html5shiv.min.js?v=3.7.3"></script>
# <![endif]-->
#                 </link>
#                </link>
#               </link>
#              </link>
#             </link>
#            </link>
#           </link>
#          </link>
#         </link>
#        </link>
#       </link>
#      </link>
#     </link>
#    </link>
#   </link>
#  </head>
#  <body class="path-node page-node-type-market-data-page has-glyphicons">
#   <!-- Link overlay -->
#   <a class="link-mobile-menu link-mobile-overlay" href="javascript:void(0)">
#   </a>
#   <!-- Link Contact -->
#   <div class="box-contact">
#    <a class="btn btn-primary btn-contact" href="https://www.epexspot.com/contact#market-operations">
#     <span>
#      Market Operations 24/7
#     </span>
#     <i class="ss-phone">
#     </i>
#    </a>
#   </div>
#   <a class="visually-hidden focusable skip-link" href="#main-content">
#    Skip to main content
#   </a>
#   <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
#    <header class="header-wrap" data-langcode="en" id="header" role="heading">
#     <div class="header-top-section">
#      <div class="container">
#       <a class="header-top-title" href="http://www.eex-group.com/eexg/" target="_blank">
#        Part of EEX Group
#       </a>
#       <ul class="list-inline header-top-nav">
#        <li class="list-inline-item">
#         <a href="https://webshop.eex-group.com/">
#          Order Market Data
#         </a>
#        </li>
#        <li class="list-inline-item">
#         <a href="https://www.elearning.epexspot.com/MosSrv/">
#          Login E-Learning
#         </a>
#        </li>
#        <li class="list-inline-item">
#         <a href="/en/downloads">
#          Downloads
#         </a>
#        </li>
#        <li class="list-inline-item">
#         <a href="/en/newsroom">
#          Newsroom
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="header-menu-section">
#      <div class="container">
#       <div class="header-mobile-block">
#        <!-- Menu Mobile -->
#        <a class="link-mobile-menu link-burger" href="javascript:void(0)">
#         <span>
#         </span>
#         <span>
#         </span>
#         <span>
#         </span>
#        </a>
#        <!-- Logo -->
#        <a class="header-logo" href="https://www.epexspot.com/en">
#         <img alt="Epex" class="logo" src="/themes/custom/epex/images/epex.svg"/>
#         <img alt="Epex" class="logo-white" src="/themes/custom/epex/images/epex-white.svg"/>
#         <span class="sr-only">
#          Epex
#         </span>
#        </a>
#        <!-- Link Contact for mobile -->
#        <a class="tel" href="https://www.epexspot.com/contact#market-operations">
#         <span class="sr-only">
#          Market Operations 24/7
#         </span>
#         <i class="ss-phone">
#         </i>
#        </a>
#        <!-- Account Mobile -->
#        <div class="link-mobile-user">
#         <a href="/en/user/login">
#          Log in
#         </a>
#        </div>
#       </div>
#       <!-- Menu -->
#       <nav class="header-main-nav" id="navbar" role="navigation">
#        <!-- Logo -->
#        <div class="header-logo-block">
#         <a class="header-nav-logo" href="https://www.epexspot.com/en">
#          <img alt="Epex" src="/themes/custom/epex/images/epex.svg"/>
#          <span class="sr-only">
#           Epex
#          </span>
#         </a>
#        </div>
#        <!-- Menu -->
#        <ul class="menu nav">
#         <li class="expanded first underlined">
#          <a href="">
#           Market data
#          </a>
#          <ul class="menu child-level">
#           <li class="first underlined">
#            <a data-drupal-link-system-path="node/180" href="/en/market-data">
#             Market Results
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/1748" href="/en/indices">
#             Indices
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/118" href="/en/marketdataservices">
#             Market Data Services
#            </a>
#           </li>
#           <li>
#            <a href="http://webshop.eex-group.com">
#             Order Market Data
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/927" href="/en/GCDataUse">
#             General Conditions of Data Use
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/935" href="/en/datavendors">
#             List of Data Vendors
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="expanded">
#          <a href="">
#           Market Access
#          </a>
#          <ul class="menu child-level">
#           <li>
#            <a data-drupal-link-system-path="node/1763" href="/en/becomeamember">
#             Become a member
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/163" href="/en/exchangemembers">
#             Exchange members
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/1789" href="/en/small-market-participants">
#             Small market participants
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/1596" href="/en/software-providers">
#             Software providers
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="expanded">
#          <a href="">
#           Trading &amp; Services
#          </a>
#          <ul class="menu child-level">
#           <li>
#            <a data-drupal-link-system-path="node/177" href="/en/tradingproducts">
#             Trading Products
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/188" href="/en/technology">
#             Technology
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/186" href="/en/fees">
#             Fees
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/117" href="/en/elearning">
#             E-Learning and Trading Handbook
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/190" href="/en/servicespx">
#             Services to other Power Exchanges
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/181" href="/en/consulting">
#             EPEX SPOT Consulting
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="expanded">
#          <a href="">
#           Markets &amp; Regulation
#          </a>
#          <ul class="menu child-level">
#           <li>
#            <a data-drupal-link-system-path="node/156" href="/en/basicspowermarket">
#             Basics of the Power Market
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/119" href="/en/marketcoupling">
#             European Market Coupling
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/176" href="/en/regulation">
#             Regulation
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/157" href="/en/marketsurveillance">
#             Market Surveillance
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/134" href="/en/glossary">
#             Glossary
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="expanded">
#          <a href="">
#           Corporate
#          </a>
#          <ul class="menu child-level">
#           <li>
#            <a data-drupal-link-system-path="node/1762" href="/en/about">
#             About EPEX SPOT
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/321" href="/en/governance">
#             Governance
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/54" href="/en/newsroom">
#             Newsroom
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/1599" href="/en/10years">
#             10 years of power
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/93" href="/en/joinepex">
#             Career
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/179" href="/en/contact">
#             Contact
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#        <!-- Link Connexion & Search -->
#        <ul class="list-add-nav list-inline">
#         <li class="list-inline-item list-user-item">
#          <a href="/en/user/login">
#           Log in
#          </a>
#         </li>
#        </ul>
#        <!-- Link -->
#        <ul class="list-inline header-top-mobile-nav">
#         <li class="list-inline-item">
#          <a href="https://webshop.eex-group.com/">
#           Order Market Data
#          </a>
#         </li>
#         <li class="list-inline-item">
#          <a href="https://www.elearning.epexspot.com/MosSrv/">
#           Login E-Learning
#          </a>
#         </li>
#         <li class="list-inline-item">
#          <a href="/en/downloads">
#           Downloads
#          </a>
#         </li>
#         <li class="list-inline-item">
#          <a href="/en/newsroom">
#           Newsroom
#          </a>
#         </li>
#        </ul>
#       </nav>
#      </div>
#     </div>
#    </header>
#    <div class="main-wrap js-quickedit-main-content" role="main">
#     <section>
#      <a id="main-content">
#      </a>
#      <div class="region region-content">
#       <section class="data-disclaimer-acceptation-form block block-epex-core block-epex-data-disclaimer clearfix" data-drupal-selector="data-disclaimer-acceptation-form" id="block-epexdatadisclaimerblock">
#        <form accept-charset="UTF-8" action="/en/market-data?market_area=DE&amp;trading_date=&amp;delivery_date=2020-01-05&amp;underlying_year=&amp;modality=Continuous&amp;sub_modality=&amp;product=60&amp;data_mode=table&amp;period=" id="data-disclaimer-acceptation-form" method="post">
#         <div class="disclaimer-wrap" id="disclaimer-block">
#          <div class="disclaimer-section">
#           <div class="row">
#            <div class="col-md-6" style="background-image:url('/sites/default/files/2019-11/kari-shea-237489-unsplash_mirrored_light.jpg')">
#             <div class="disclaimer-img-block">
#              <h2 class="disclaimer-title">
#               Welcome to EPEX SPOT!
#              </h2>
#              <button class="btn btn-white-outline button js-form-submit form-submit btn-default" data-drupal-selector="edit-acceptationbutton" id="edit-acceptationbutton" name="op" type="submit" value="Access to EPEX Spot website ">
#               Access to EPEX Spot website
#               <i class="icon-chevron-right">
#               </i>
#              </button>
#             </div>
#            </div>
#            <div class="col-md-6">
#             <div class="disclaimer-block">
#              <h3>
#               General conditions
#              </h3>
#              <div>
#               <p>
#                Any user of this website expressly agrees to the Conditions of Use published in the
#                <a href="https://www.epexspot.com/en/Privacy">
#                 Privacy Notice
#                </a>
#                and the
#                <a href="https://www.epexspot.com/en/UseofWebsite">
#                 Usage of Website
#                </a>
#                .
#               </p>
#               <p>
#               </p>
#              </div>
#              <h3>
#               Market Data Use
#              </h3>
#              <div>
#               <p>
#                The content of the Website is to be used exclusively for internal reasons. Commercial usage is only allowed after explicit approval of EPEX SPOT. Please click
#                <a href="http://static.epexspot.com/document/40851/General%20Conditions%20Market%20Data">
#                 here
#                </a>
#                for General Conditions of Data Use.
#               </p>
#              </div>
#              <br/>
#              <button class="btn btn-primary-outline button js-form-submit form-submit btn-default" data-drupal-selector="edit-acceptationbuttonmobile" id="edit-acceptationbuttonmobile" name="op" type="submit" value="Access to EPEX Spot website ">
#               Access to EPEX Spot website
#               <i class="icon-chevron-right">
#               </i>
#              </button>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <input autocomplete="off" data-drupal-selector="form-1jlunl-ghzfkrontvxpb3bzyxu7jrnk5solx0-lmmys" name="form_build_id" type="hidden" value="form-1JlUNl_GhzFKRoNTVXPB3BZyxu7JrNk5sOLX0_LmmYs"/>
#         <input data-drupal-selector="edit-data-disclaimer-acceptation-form" name="form_id" type="hidden" value="data_disclaimer_acceptation_form"/>
#        </form>
#       </section>
#       <div class="page-wrap" data-timezone="Europe/Paris" id="epex-md-common-data-container">
#        <div class="js-md-page-wrap">
#         <section class="filter-section">
#          <div class="filter-bloc">
#           <a class="toggle-filter" href="#">
#            <i class="zmdi zmdi-chevron-up">
#            </i>
#            Filters
#           </a>
#           <h1 class="sr-only" data-aos="fade-left" data-aos-delay="400" data-aos-duration="500">
#            Market Data
#           </h1>
#           <div class="filter-content" data-aos="fade-up" data-aos-delay="400" data-aos-duration="500" id="md_filters_wrapper">
#            <form accept-charset="UTF-8" action="/en/market-data?market_area=DE&amp;trading_date=&amp;delivery_date=2020-01-05&amp;underlying_year=&amp;modality=Continuous&amp;sub_modality=&amp;product=60&amp;data_mode=table&amp;period=" class="market-data-filters-form" data-drupal-selector="market-data-filters-form" id="market-data-filters-form" method="post">
#             <div class="form-head">
#              <span>
#               Select your filters
#              </span>
#              <button class="reset-filters js-md-filters-reset button js-form-submit form-submit btn-primary btn icon-before" data-drupal-selector="edit-actions-reset" formnovalidate="formnovalidate" id="edit-actions-reset" name="reset" type="submit" value=" Reset filters">
#               <span aria-hidden="true" class="icon glyphicon glyphicon-filter">
#               </span>
#               <i class="icon-reset">
#               </i>
#               Reset filters
#              </button>
#             </div>
#             <div class="scroll-bloc">
#              <span class="group-input-title">
#               Trading Modality
#              </span>
#              <div class="group-input inline-input three-cols">
#               <div class="form-item js-form-item form-type-radio js-form-type-radio form-item-filters-modality js-form-item-filters-modality radio">
#                <label class="control-label option" for="edit-filters-modality-auction">
#                 <input class="md-filter-modality js-filter-modality form-radio" data-drupal-selector="edit-filters-modality-auction" id="edit-filters-modality-auction" name="filters[modality]" type="radio" value="Auction"/>
#                 <span class="label">
#                  Auction
#                 </span>
#                </label>
#               </div>
#               <div class="form-item js-form-item form-type-radio js-form-type-radio form-item-filters-modality js-form-item-filters-modality radio">
#                <label class="control-label option" for="edit-filters-modality-continuous">
#                 <input checked="checked" class="md-filter-modality js-filter-modality form-radio" data-drupal-selector="edit-filters-modality-continuous" id="edit-filters-modality-continuous" name="filters[modality]" type="radio" value="Continuous"/>
#                 <span class="label">
#                  Continuous
#                 </span>
#                </label>
#               </div>
#               <div class="form-item js-form-item form-type-radio js-form-type-radio form-item-filters-modality js-form-item-filters-modality radio">
#                <label class="control-label option" for="edit-filters-modality-capacity">
#                 <input class="md-filter-modality js-filter-modality form-radio" data-drupal-selector="edit-filters-modality-capacity" id="edit-filters-modality-capacity" name="filters[modality]" type="radio" value="Capacity"/>
#                 <span class="label">
#                  Capacity Auction
#                 </span>
#                </label>
#               </div>
#              </div>
#              <div class="row row-select">
#               <div class="col-sm-6">
#                <span class="group-input-title">
#                 Delivery Date
#                </span>
#                <div class="form-select">
#                 <div class="select-wrapper">
#                  <select class="md-filter-delivery_date js-filter-delivery_date form-select form-control" data-drupal-selector="edit-filters-delivery-date" id="edit-filters-delivery-date" name="filters[delivery_date]">
#                   <option value="2020-01-06">
#                    06 Jan. 2020
#                   </option>
#                   <option selected="selected" value="2020-01-05">
#                    05 Jan. 2020
#                   </option>
#                   <option value="2020-01-04">
#                    04 Jan. 2020
#                   </option>
#                  </select>
#                 </div>
#                </div>
#               </div>
#              </div>
#              <span class="group-input-title">
#               Product
#              </span>
#              <div class="group-input inline-input three-cols">
#               <div class="form-item js-form-item form-type-radio js-form-type-radio form-item-filters-product js-form-item-filters-product radio">
#                <label class="control-label option" for="edit-filters-product-60">
#                 <input checked="checked" class="md-filter-product js-filter-product form-radio" data-drupal-selector="edit-filters-product-60" id="edit-filters-product-60" name="filters[product]" type="radio" value="60"/>
#                 <span class="label">
#                  60 min
#                 </span>
#                </label>
#               </div>
#               <div class="form-item js-form-item form-type-radio js-form-type-radio form-item-filters-product js-form-item-filters-product radio">
#                <label class="control-label option" for="edit-filters-product-30">
#                 <input class="md-filter-product js-filter-product form-radio" data-drupal-selector="edit-filters-product-30" id="edit-filters-product-30" name="filters[product]" type="radio" value="30"/>
#                 <span class="label">
#                  30 min
#                 </span>
#                </label>
#               </div>
#               <div class="form-item js-form-item form-type-radio js-form-type-radio form-item-filters-product js-form-item-filters-product radio">
#                <label class="control-label option" for="edit-filters-product-15">
#                 <input class="md-filter-product js-filter-product form-radio" data-drupal-selector="edit-filters-product-15" id="edit-filters-product-15" name="filters[product]" type="radio" value="15"/>
#                 <span class="label">
#                  15 min
#                 </span>
#                </label>
#               </div>
#              </div>
#              <span class="group-input-title">
#               View
#              </span>
#              <div class="group-input inline-input three-col">
#               <div class="form-item js-form-item form-type-radio js-form-type-radio form-item-filters-data-mode js-form-item-filters-data-mode radio">
#                <label class="control-label option" for="edit-filters-data-mode-map">
#                 <input class="md-filter-data_mode js-filter-data_mode form-radio" data-drupal-selector="edit-filters-data-mode-map" id="edit-filters-data-mode-map" name="filters[data_mode]" type="radio" value="map"/>
#                 <span class="label">
#                  Map
#                 </span>
#                </label>
#               </div>
#               <div class="form-item js-form-item form-type-radio js-form-type-radio form-item-filters-data-mode js-form-item-filters-data-mode radio">
#                <label class="control-label option" for="edit-filters-data-mode-table">
#                 <input checked="checked" class="md-filter-data_mode js-filter-data_mode form-radio" data-drupal-selector="edit-filters-data-mode-table" id="edit-filters-data-mode-table" name="filters[data_mode]" type="radio" value="table"/>
#                 <span class="label">
#                  Table
#                 </span>
#                </label>
#               </div>
#               <div class="form-item js-form-item form-type-radio js-form-type-radio form-item-filters-data-mode js-form-item-filters-data-mode radio">
#                <label class="control-label option" for="edit-filters-data-mode-graph">
#                 <input class="md-filter-data_mode js-filter-data_mode form-radio" data-drupal-selector="edit-filters-data-mode-graph" id="edit-filters-data-mode-graph" name="filters[data_mode]" type="radio" value="graph"/>
#                 <span class="label">
#                  Graph
#                 </span>
#                </label>
#               </div>
#              </div>
#              <span class="group-input-title">
#               Market Area
#              </span>
#              <div class="group-input inline-input five-cols">
#               <div class="form-item js-form-item form-type-radio js-form-type-radio form-item-filters-market-area js-form-item-filters-market-area radio">
#                <label class="control-label option" for="edit-filters-market-area-at">
#                 <input class="md-filter-market_area js-filter-market_area form-radio" data-drupal-selector="edit-filters-market-area-at" id="edit-filters-market-area-at" name="filters[market_area]" type="radio" value="AT"/>
#                 <span class="label">
#                  AT
#                 </span>
#                </label>
#               </div>
#               <div class="form-item js-form-item form-type-radio js-form-type-radio form-item-filters-market-area js-form-item-filters-market-area radio">
#                <label class="control-label option" for="edit-filters-market-area-be">
#                 <input class="md-filter-market_area js-filter-market_area form-radio" data-drupal-selector="edit-filters-market-area-be" id="edit-filters-market-area-be" name="filters[market_area]" type="radio" value="BE"/>
#                 <span class="label">
#                  BE
#                 </span>
#                </label>
#               </div>
#               <div class="form-item js-form-item form-type-radio js-form-type-radio form-item-filters-market-area js-form-item-filters-market-area radio">
#                <label class="control-label option" for="edit-filters-market-area-ch">
#                 <input class="md-filter-market_area js-filter-market_area form-radio" data-drupal-selector="edit-filters-market-area-ch" id="edit-filters-market-area-ch" name="filters[market_area]" type="radio" value="CH"/>
#                 <span class="label">
#                  CH
#                 </span>
#                </label>
#               </div>
#               <div class="form-item js-form-item form-type-radio js-form-type-radio form-item-filters-market-area js-form-item-filters-market-area radio">
#                <label class="control-label option" for="edit-filters-market-area-de">
#                 <input checked="checked" class="md-filter-market_area js-filter-market_area form-radio" data-drupal-selector="edit-filters-market-area-de" id="edit-filters-market-area-de" name="filters[market_area]" type="radio" value="DE"/>
#                 <span class="label">
#                  DE
#                 </span>
#                </label>
#               </div>
#               <div class="form-item js-form-item form-type-radio js-form-type-radio form-item-filters-market-area js-form-item-filters-market-area radio">
#                <label class="control-label option" for="edit-filters-market-area-fr">
#                 <input class="md-filter-market_area js-filter-market_area form-radio" data-drupal-selector="edit-filters-market-area-fr" id="edit-filters-market-area-fr" name="filters[market_area]" type="radio" value="FR"/>
#                 <span class="label">
#                  FR
#                 </span>
#                </label>
#               </div>
#               <div class="form-item js-form-item form-type-radio js-form-type-radio form-item-filters-market-area js-form-item-filters-market-area radio">
#                <label class="control-label option" for="edit-filters-market-area-nl">
#                 <input class="md-filter-market_area js-filter-market_area form-radio" data-drupal-selector="edit-filters-market-area-nl" id="edit-filters-market-area-nl" name="filters[market_area]" type="radio" value="NL"/>
#                 <span class="label">
#                  NL
#                 </span>
#                </label>
#               </div>
#              </div>
#              <div class="btns">
#               <a class="btn btn-primary-outline btn-full btn-see-results" href="javascripts:void(0)">
#                See Results
#               </a>
#               <a class="btn btn-dark-outline btn-full btn-see-all" href="https://webshop.eex-group.com/" target="_blank">
#                Access Data in Webshop
#                <i class="icon-chevron-right">
#                </i>
#               </a>
#               <button class="reset-filters js-md-filters-reset button js-form-submit form-submit btn-primary btn icon-before" data-drupal-selector="edit-actions-reset-mobile" formnovalidate="formnovalidate" id="edit-actions-reset-mobile" name="reset_mobile" type="submit" value=" Reset filters">
#                <span aria-hidden="true" class="icon glyphicon glyphicon-filter">
#                </span>
#                <i class="icon-reset">
#                </i>
#                Reset filters
#               </button>
#              </div>
#             </div>
#             <input class="js-filter-triggered_element" data-drupal-selector="edit-triggered-element" name="triggered_element" type="hidden" value=""/>
#             <button class="js-hide js-md-filters-submit button js-form-submit form-submit btn-default btn" data-drupal-selector="edit-submit-js" id="edit-submit-js" name="submit_js" type="submit" value="">
#             </button>
#             <input autocomplete="off" data-drupal-selector="form-hasxaeebjhotfnxt3g1uhfytdbs5c-prqrcyfkki7py" name="form_build_id" type="hidden" value="form-hasxAEEBJhOTfNXT3G1UhfytdBs5c_pRQrCyFKKI7PY"/>
#             <input data-drupal-selector="edit-market-data-filters-form" name="form_id" type="hidden" value="market_data_filters_form"/>
#            </form>
#           </div>
#          </div>
#          <div class="loading js-md-spinner">
#           <span>
#            Loading...
#           </span>
#          </div>
#          <div class="content js-md-widget">
#           <!-- Notifications-->
#           <!-- Table -->
#           <div class="table-container">
#            <h2>
#             Continuous &gt;
#                                                     60min &gt;
#                                         DE
#                          &gt;
#                                     05 January 2020
#            </h2>
#            <span class="last-update">
#             Last update:
#                 05 January 2020
#                 (04:30:01 CET/CEST)
#            </span>
#            <div class="custom-tables 60min">
#             <div class="fixed-column js-table-times">
#              <span class="fixed-head-column">
#               Hours
#              </span>
#              <ul>
#               <!-- level-0 -->
#               <li class="child" data-hour="0">
#                <a href="#">
#                 00 - 01
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="1" data-hour="0">
#                <a href="#">
#                 00:00 - 00:30
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="0">
#                <a href="#">
#                 00:00 - 00:15
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="0">
#                <a href="#">
#                 00:15 - 00:30
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="2" data-hour="0">
#                <a href="#">
#                 00:30 - 01:00
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="0">
#                <a href="#">
#                 00:30 - 00:45
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="0">
#                <a href="#">
#                 00:45 - 01:00
#                </a>
#               </li>
#               <!-- level-0 -->
#               <li class="child impair" data-hour="1">
#                <a href="#">
#                 01 - 02
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="1" data-hour="1">
#                <a href="#">
#                 01:00 - 01:30
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="1">
#                <a href="#">
#                 01:00 - 01:15
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="1">
#                <a href="#">
#                 01:15 - 01:30
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="2" data-hour="1">
#                <a href="#">
#                 01:30 - 02:00
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="1">
#                <a href="#">
#                 01:30 - 01:45
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="1">
#                <a href="#">
#                 01:45 - 02:00
#                </a>
#               </li>
#               <!-- level-0 -->
#               <li class="child" data-hour="2">
#                <a href="#">
#                 02 - 03
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="1" data-hour="2">
#                <a href="#">
#                 02:00 - 02:30
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="2">
#                <a href="#">
#                 02:00 - 02:15
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="2">
#                <a href="#">
#                 02:15 - 02:30
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="2" data-hour="2">
#                <a href="#">
#                 02:30 - 03:00
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="2">
#                <a href="#">
#                 02:30 - 02:45
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="2">
#                <a href="#">
#                 02:45 - 03:00
#                </a>
#               </li>
#               <!-- level-0 -->
#               <li class="child impair" data-hour="3">
#                <a href="#">
#                 03 - 04
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="1" data-hour="3">
#                <a href="#">
#                 03:00 - 03:30
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="3">
#                <a href="#">
#                 03:00 - 03:15
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="3">
#                <a href="#">
#                 03:15 - 03:30
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="2" data-hour="3">
#                <a href="#">
#                 03:30 - 04:00
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="3">
#                <a href="#">
#                 03:30 - 03:45
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="3">
#                <a href="#">
#                 03:45 - 04:00
#                </a>
#               </li>
#               <!-- level-0 -->
#               <li class="child" data-hour="4">
#                <a href="#">
#                 04 - 05
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="1" data-hour="4">
#                <a href="#">
#                 04:00 - 04:30
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="4">
#                <a href="#">
#                 04:00 - 04:15
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="4">
#                <a href="#">
#                 04:15 - 04:30
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="2" data-hour="4">
#                <a href="#">
#                 04:30 - 05:00
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="4">
#                <a href="#">
#                 04:30 - 04:45
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="4">
#                <a href="#">
#                 04:45 - 05:00
#                </a>
#               </li>
#               <!-- level-0 -->
#               <li class="child impair" data-hour="5">
#                <a href="#">
#                 05 - 06
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="1" data-hour="5">
#                <a href="#">
#                 05:00 - 05:30
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="5">
#                <a href="#">
#                 05:00 - 05:15
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="5">
#                <a href="#">
#                 05:15 - 05:30
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="2" data-hour="5">
#                <a href="#">
#                 05:30 - 06:00
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="5">
#                <a href="#">
#                 05:30 - 05:45
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="5">
#                <a href="#">
#                 05:45 - 06:00
#                </a>
#               </li>
#               <!-- level-0 -->
#               <li class="child" data-hour="6">
#                <a href="#">
#                 06 - 07
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="1" data-hour="6">
#                <a href="#">
#                 06:00 - 06:30
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="6">
#                <a href="#">
#                 06:00 - 06:15
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="6">
#                <a href="#">
#                 06:15 - 06:30
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="2" data-hour="6">
#                <a href="#">
#                 06:30 - 07:00
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="6">
#                <a href="#">
#                 06:30 - 06:45
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="6">
#                <a href="#">
#                 06:45 - 07:00
#                </a>
#               </li>
#               <!-- level-0 -->
#               <li class="child impair" data-hour="7">
#                <a href="#">
#                 07 - 08
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="1" data-hour="7">
#                <a href="#">
#                 07:00 - 07:30
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="7">
#                <a href="#">
#                 07:00 - 07:15
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="7">
#                <a href="#">
#                 07:15 - 07:30
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="2" data-hour="7">
#                <a href="#">
#                 07:30 - 08:00
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="7">
#                <a href="#">
#                 07:30 - 07:45
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="7">
#                <a href="#">
#                 07:45 - 08:00
#                </a>
#               </li>
#               <!-- level-0 -->
#               <li class="child" data-hour="8">
#                <a href="#">
#                 08 - 09
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="1" data-hour="8">
#                <a href="#">
#                 08:00 - 08:30
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="8">
#                <a href="#">
#                 08:00 - 08:15
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="8">
#                <a href="#">
#                 08:15 - 08:30
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="2" data-hour="8">
#                <a href="#">
#                 08:30 - 09:00
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="8">
#                <a href="#">
#                 08:30 - 08:45
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="8">
#                <a href="#">
#                 08:45 - 09:00
#                </a>
#               </li>
#               <!-- level-0 -->
#               <li class="child impair" data-hour="9">
#                <a href="#">
#                 09 - 10
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="1" data-hour="9">
#                <a href="#">
#                 09:00 - 09:30
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="9">
#                <a href="#">
#                 09:00 - 09:15
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="1" data-hour="9">
#                <a href="#">
#                 09:15 - 09:30
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="2" data-hour="9">
#                <a href="#">
#                 09:30 - 10:00
#                </a>
#               </li>
#               <!-- level-2 -->
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="9">
#                <a href="#">
#                 09:30 - 09:45
#                </a>
#               </li>
#               <li class="sub-child lvl-2" data-half-hour="2" data-hour="9">
#                <a href="#">
#                 09:45 - 10:00
#                </a>
#               </li>
#               <!-- level-0 -->
#               <li class="child" data-hour="10">
#                <a href="#">
#                 10 - 11
#                </a>
#               </li>
#               <!-- level-1 -->
#               <li class="sub-child lvl-1" data-half-hour="1" data-hour="10">
#                <a href="#">
# ...
#              here
#             </a>
#             for full terms and conditions on the usage of market data.
#            </p>
#           </div>
#          </div>
#          <div class="js-md-sidebar">
#          </div>
#         </section>
#         <div class="content-wrap js-md-content">
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#     <a class="btn btn-primary btn-top" href="javascript:void(0)">
#      <i class="icon-chevron-up">
#      </i>
#     </a>
#    </div>
#    <footer class="footer-wrap" id="footer" role="contentinfo">
#     <div class="container">
#      <!-- Menu -->
#      <div class="footer-menu-section row">
#       <div class="col-md-2">
#        <!-- Logo -->
#        <a class="footer-logo" href="https://www.epexspot.com/en">
#         <img alt="Epex" src="/themes/custom/epex/images/epex-white.svg"/>
#         <span class="sr-only">
#          Epex
#         </span>
#        </a>
#        <!-- Address -->
#        <div class="address-block">
#         <div>
#          5 Boulevard Montmartre
# 75002 Paris
#         </div>
#         <span class="phone-number">
#          +33 (0)1 73 03 96 00
#         </span>
#         <br/>
#         <a class="mail" href="mailto:info@epexspot.com">
#          info@epexspot.com
#         </a>
#        </div>
#       </div>
#       <div class="col-md-10">
#        <ul class="menu nav">
#         <li class="expanded first underlined">
#          <a href="">
#           Market data
#          </a>
#          <ul class="menu child-level">
#           <li class="first underlined">
#            <a data-drupal-link-system-path="node/180" href="/en/market-data">
#             Market Results
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/1748" href="/en/indices">
#             Indices
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/118" href="/en/marketdataservices">
#             Market Data Services
#            </a>
#           </li>
#           <li>
#            <a href="http://webshop.eex-group.com">
#             Order Market Data
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/927" href="/en/GCDataUse">
#             General Conditions of Data Use
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/935" href="/en/datavendors">
#             List of Data Vendors
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="expanded">
#          <a href="">
#           Market Access
#          </a>
#          <ul class="menu child-level">
#           <li>
#            <a data-drupal-link-system-path="node/1763" href="/en/becomeamember">
#             Become a member
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/163" href="/en/exchangemembers">
#             Exchange members
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/1789" href="/en/small-market-participants">
#             Small Market Participants
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/1596" href="/en/software-providers">
#             Software providers
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="expanded">
#          <a href="">
#           Trading &amp; Services
#          </a>
#          <ul class="menu child-level">
#           <li>
#            <a data-drupal-link-system-path="node/177" href="/en/tradingproducts">
#             Trading Products
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/188" href="/en/technology">
#             Technology
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/186" href="/en/fees">
#             Fees
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/117" href="/en/elearning">
#             E-Learning and Trading Handbook
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/190" href="/en/servicespx">
#             Services to other Power Exchanges
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/181" href="/en/consulting">
#             EPEX SPOT Consulting
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="expanded">
#          <a href="">
#           Market Regulation
#          </a>
#          <ul class="menu child-level">
#           <li>
#            <a data-drupal-link-system-path="node/156" href="/en/basicspowermarket">
#             Basics of the Power Market
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/119" href="/en/marketcoupling">
#             European Market Coupling
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/176" href="/en/regulation">
#             Regulation
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/157" href="/en/marketsurveillance">
#             Market Surveillance
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/134" href="/en/glossary">
#             Glossary
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="expanded">
#          <a href="">
#           Corporate
#          </a>
#          <ul class="menu child-level">
#           <li>
#            <a data-drupal-link-system-path="node/1762" href="/en/about">
#             About EPEX SPOT
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/321" href="/en/governance">
#             Governance
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/54" href="/en/newsroom">
#             Newsroom
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/1599" href="/en/10years">
#             10 years of power
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/93" href="/en/joinepex">
#             Career
#            </a>
#           </li>
#           <li>
#            <a data-drupal-link-system-path="node/179" href="/en/contact">
#             Contact
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <!-- Links -->
#      <div class="footer-link-section">
#       <ul class="footer-link-nav list-inline">
#        <li class="list-inline-item">
#         <a href="https://webshop.eex-group.com">
#          Webshop
#         </a>
#        </li>
#        <li class="list-inline-item">
#         <a href="https://www.elearning.epexspot.com/MosSrv/">
#          Login E-learning
#         </a>
#        </li>
#        <li class="list-inline-item">
#         <a href="/en/downloads">
#          Downloads
#         </a>
#        </li>
#        <li class="list-inline-item">
#         <a href="/en/newsroom">
#          Newsroom
#         </a>
#        </li>
#       </ul>
#       <ul class="list-socials list-inline">
#        <li class="list-inline-item">
#         <a href="https://www.linkedin.com/company/epex-spot/?originalSubdomain=fr" target="_blank">
#          <i class="zmdi zmdi-linkedin">
#          </i>
#          Follow us on LinkedIn
#         </a>
#        </li>
#        <li class="list-inline-item">
#         <a href="https://twitter.com/epexspot_se" target="_blank">
#          <i class="zmdi zmdi-twitter">
#          </i>
#          Follow us on Twitter
#         </a>
#        </li>
#       </ul>
#      </div>
#      <!-- EEX Group -->
#      <div class="related-section">
#       <div class="related-text">
#        Part of
#        <a class="related-img" href="http://www.eex-group.com/eexg/" target="_blank">
#         <img alt="eexgroup" src="/themes/custom/epex/images/eexgroup.svg"/>
#        </a>
#        <span class="sr-only">
#         eex
#        </span>
#       </div>
#       <div class="related-block">
#        Related website
#        <a class="btn btn-eex" href="https://webshop.eex-group.com" target="_blank">
#         webshop.eex-group.com
#        </a>
#       </div>
#      </div>
#      <!-- Copyright -->
#      <div class="copyright-section">
#       <div class="copyright-block">
#        <div class="copyright-text">
#         ©2020 EPEX SPOT. All rights reserved
#        </div>
#        <ul class="copyright-nav list-inline">
#         <li class="list-inline-item">
#          <a href="/en/UseofWebsite">
#           Terms of Use of the Website
#          </a>
#         </li>
#         <li class="list-inline-item">
#          <a href="/en/Privacy">
#           Privacy Policy
#          </a>
#         </li>
#         <li class="list-inline-item">
#          <a href="http://static.epexspot.com/document/40851/General%20Conditions%20Market%20Data">
#           General Conditions EPEX SPOT Market Data
#          </a>
#         </li>
#         <li class="list-inline-item">
#          <a href="/en/GCElearning">
#           General Conditions EPEX SPOT E-Learning
#          </a>
#         </li>
#        </ul>
#       </div>
#       <!-- Kernix -->
#       <div class="kernix-block">
#        Made by
#        <a href="https://www.kernix.com/" target="_blank">
#         Kernix
#         <i class="icon-kernix">
#         </i>
#        </a>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <script data-drupal-selector="drupal-settings-json" type="application/json">
#    {"path":{"baseUrl":"\/","scriptPath":null,"pathPrefix":"en\/","currentPath":"node\/180","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"en","currentQuery":{"data_mode":"table","delivery_date":"2020-01-05","market_area":"DE","modality":"Continuous","period":"","product":"60","sub_modality":"","trading_date":"","underlying_year":""}},"pluralDelimiter":"\u0003","ajaxPageState":{"libraries":"bootstrap\/popover,bootstrap\/tooltip,core\/html5shiv,core\/jquery.form,epex\/global-scripts,epex\/global-styling,epex\/highcharts,epex_core\/data-disclaimer,epex_market_data\/filters,epex_market_data\/tables,eu_cookie_compliance\/eu_cookie_compliance,statistics\/drupal.statistics,system\/base","theme":"epex","theme_token":null},"ajaxTrustedUrl":{"form_action_p_pvdeGsVG5zNF_XLGPTvYSKCf43t8qZYSwcfZl2uzM":true,"\/en\/market-data?market_area=DE\u0026trading_date=\u0026delivery_date=2020-01-05\u0026underlying_year=\u0026modality=Continuous\u0026sub_modality=\u0026product=60\u0026data_mode=table\u0026period=\u0026ajax_form=1":true,"\/en\/search\/node":true},"eu_cookie_compliance":{"popup_enabled":true,"popup_agreed_enabled":false,"popup_hide_agreed":false,"popup_clicking_confirmation":false,"popup_scrolling_confirmation":false,"popup_html_info":"\u003Cdiv class=\u0022eu-cookie-compliance-banner eu-cookie-compliance-banner-info\u0022\u003E\n  \u003Cdiv class=\u0022popup-content info eu-cookie-compliance-content\u0022\u003E\n    \u003Cdiv id=\u0022popup-text\u0022 class=\u0022eu-cookie-compliance-message\u0022\u003E\n      \u003Ch2\u003EWe use cookies on this site to enhance your user experience\u003C\/h2\u003E\n\u003Cp\u003EBy clicking any link on this page you are giving your consent for us to set cookies.\u003C\/p\u003E\n\n              \u003Cbutton type=\u0022button\u0022 class=\u0022find-more-button eu-cookie-compliance-more-button\u0022\u003EMore info\u003C\/button\u003E\n          \u003C\/div\u003E\n    \u003Cdiv id=\u0022popup-buttons\u0022 class=\u0022eu-cookie-compliance-buttons\u0022\u003E\n      \u003Cbutton type=\u0022button\u0022 class=\u0022agree-button eu-cookie-compliance-secondary-button\u0022\u003EOK, I agree\u003C\/button\u003E\n              \u003Cbutton type=\u0022button\u0022 class=\u0022decline-button eu-cookie-compliance-default-button\u0022 \u003ENo, thanks\u003C\/button\u003E\n          \u003C\/div\u003E\n  \u003C\/div\u003E\n\u003C\/div\u003E","use_mobile_message":false,"mobile_popup_html_info":"\u003Cdiv class=\u0022eu-cookie-compliance-banner eu-cookie-compliance-banner-info\u0022\u003E\n  \u003Cdiv class=\u0022popup-content info eu-cookie-compliance-content\u0022\u003E\n    \u003Cdiv id=\u0022popup-text\u0022 class=\u0022eu-cookie-compliance-message\u0022\u003E\n      \n              \u003Cbutton type=\u0022button\u0022 class=\u0022find-more-button eu-cookie-compliance-more-button\u0022\u003EMore info\u003C\/button\u003E\n          \u003C\/div\u003E\n    \u003Cdiv id=\u0022popup-buttons\u0022 class=\u0022eu-cookie-compliance-buttons\u0022\u003E\n      \u003Cbutton type=\u0022button\u0022 class=\u0022agree-button eu-cookie-compliance-secondary-button\u0022\u003EOK, I agree\u003C\/button\u003E\n              \u003Cbutton type=\u0022button\u0022 class=\u0022decline-button eu-cookie-compliance-default-button\u0022 \u003ENo, thanks\u003C\/button\u003E\n          \u003C\/div\u003E\n  \u003C\/div\u003E\n\u003C\/div\u003E","mobile_breakpoint":768,"popup_html_agreed":false,"popup_use_bare_css":false,"popup_height":"auto","popup_width":"100%","popup_delay":1000,"popup_link":"https:\/\/www.epexspot.com\/en\/cookies-policy","popup_link_new_window":true,"popup_position":false,"popup_language":"en","store_consent":false,"better_support_for_screen_readers":false,"cookie_name":"","reload_page":false,"domain":"","popup_eu_only_js":false,"cookie_lifetime":100,"cookie_session":0,"disagree_do_not_show_popup":false,"method":"opt_in","whitelisted_cookies":"","withdraw_markup":"\u003Cbutton type=\u0022button\u0022 class=\u002 ...
#   </script>
#   <script src="/core/assets/vendor/domready/ready.min.js?v=1.0.8">
#   </script>
#   <script src="/core/assets/vendor/jquery/jquery.min.js?v=3.2.1">
#   </script>
#   <script src="/core/assets/vendor/underscore/underscore-min.js?v=1.8.3">
#   </script>
#   <script src="/core/assets/vendor/jquery-once/jquery.once.min.js?v=2.2.0">
#   </script>
#   <script src="/core/misc/drupalSettingsLoader.js?v=8.6.13">
#   </script>
#   <script src="/core/misc/drupal.js?v=8.6.13">
#   </script>
#   <script src="/core/misc/drupal.init.js?v=8.6.13">
#   </script>
#   <script src="/modules/custom/epex_core/modules/epex_market_data/js/md-filters.js?q3dd6r">
#   </script>
#   <script src="/modules/custom/epex_core/modules/epex_market_data/js/md-common.js?q3dd6r">
#   </script>
#   <script src="/modules/custom/epex_core/modules/epex_market_data/js/md-tables.js?q3dd6r">
#   </script>
#   <script src="/themes/contrib/bootstrap/js/drupal.bootstrap.js?q3dd6r">
#   </script>
#   <script src="/themes/contrib/bootstrap/js/attributes.js?q3dd6r">
#   </script>
#   <script src="/themes/contrib/bootstrap/js/theme.js?q3dd6r">
#   </script>
#   <script src="/themes/custom/epex/js/affix.js?q3dd6r">
#   </script>
#   <script src="/themes/custom/epex/lib/owl.carousel/dist/owl.carousel.js?q3dd6r">
#   </script>
#   <script src="/themes/custom/epex/js/main.js?q3dd6r">
#   </script>
#   <script src="/themes/custom/epex/lib/highcharts/highstock.js?q3dd6r">
#   </script>
#   <script src="/themes/custom/epex/lib/highcharts/drag-panes.js?q3dd6r">
#   </script>
#   <script src="/themes/custom/epex/lib/highcharts/indicators.js?q3dd6r">
#   </script>
#   <script src="/themes/custom/epex/lib/highcharts/volume-by-price.js?q3dd6r">
#   </script>
#   <script src="/core/assets/vendor/jquery.cookie/jquery.cookie.min.js?v=1.4.1">
#   </script>
#   <script src="/modules/contrib/eu_cookie_compliance/js/eu_cookie_compliance.js?v=1">
#   </script>
#   <script src="/themes/contrib/bootstrap/js/popover.js?q3dd6r">
#   </script>
#   <script src="/themes/contrib/bootstrap/js/tooltip.js?q3dd6r">
#   </script>
#   <script src="/core/modules/statistics/statistics.js?v=8.6.13">
#   </script>
#   <script src="/core/misc/progress.js?v=8.6.13">
#   </script>
#   <script src="/themes/contrib/bootstrap/js/misc/progress.js?q3dd6r">
#   </script>
#   <script src="/core/misc/ajax.js?v=8.6.13">
#   </script>
#   <script src="/themes/contrib/bootstrap/js/misc/ajax.js?q3dd6r">
#   </script>
#   <script src="/core/modules/history/js/history.js?v=8.6.13">
#   </script>
#   <script src="/core/assets/vendor/jquery-form/jquery.form.min.js?v=4.22">
#   </script>
#   <script src="/modules/custom/epex_core/js/data-disclaimer.js?q3dd6r">
#   </script>
#  </body>
# </html>

# %%
#Extracting the table

#"table" is the tag while class is the attribute always distinguished by an '_'
epex_table = soup.find_all("table", class_= "table-01")

#Checking how many tables have been downloaded (class is unique)
print(len(epex_table))

#Gets a portion of the HTML content which was previously stored in soup (Extracts the only result)
epex_table = epex_table[0]

#Check for its type
print(type(epex_table))
# Out:
# 1
# <class 'bs4.element.Tag'>

# %%
#Extracting the column names

epex_cols = []

for row in epex_table.find_all('tr'):
    for cell in row.find_all('th'):
        epex_cols.append(cell.text.strip())
        
del epex_cols[0]
print(epex_cols)
# Out:
# ['Low(€/MWh)', 'High(€/MWh)', 'Last(€/MWh)', 'Weight Avg.(€/MWh)', 'Buy Volume(MWh)', 'Sell Volume(MWh)', 'Volume(MWh)']

# %%
#Extracting each element of each row in the epex_table

table = []

for row in epex_table.find_all('tr'):
    r = []
    for value in row.find_all('td'):
        r.append(value.text)
    table.append(r)

del table[0:2]

table_cols = pd.DataFrame(table, columns = epex_cols)
table_cols.head()
# Out:
#   Low(€/MWh) High(€/MWh) Last(€/MWh) Weight Avg.(€/MWh) Buy Volume(MWh)  \
# 0      16.09       35.45       26.00              30.24         3,117.5
# 1          -           -           -                  -               -
# 2     -21.99       40.09      -21.99              23.08           337.0
# 3      10.00       31.19       18.90              24.95           198.4
# 4          -           -           -                  -               -
#
#   Sell Volume(MWh) Volume(MWh)
# 0          2,670.9     2,894.2
# 1                -           -
# 2            311.5       324.2
# 3            195.9       197.1
# 4                -           -

# %%
#Extracting the hours column from the HTML content (for this website it is embedded in the <a href> tag)

hours_text = []
for a in soup.find_all('a'): 
     hours_text.append(a.text)
        
#Obtain the index of the required elements
i_1 = hours_text.index('00 - 01')
print(hours_text.index('00 - 01'))

i_2 = hours_text.index('23:45 - 24:00')
print(hours_text.index('23:45 - 24:00'))

i_end = i_2 + 1

#Using their indices, extract these elements
hours = hours_text[i_1: i_end]

#Add hours list to the table_cols dataframe
table_cols['Hours'] = hours

#Rearrange the columns
table_cols = table_cols[['Hours', 'Low(€/MWh)', 'High(€/MWh)', 'Last(€/MWh)', 'Weight Avg.(€/MWh)', 'Buy Volume(MWh)', 'Sell Volume(MWh)', 'Volume(MWh)' ]]

#View the result
table_cols.head()
# Out:
# 57
# 224
#            Hours Low(€/MWh) High(€/MWh) Last(€/MWh) Weight Avg.(€/MWh)  \
# 0        00 - 01      16.09       35.45       26.00              30.24
# 1  00:00 - 00:30          -           -           -                  -
# 2  00:00 - 00:15     -21.99       40.09      -21.99              23.08
# 3  00:15 - 00:30      10.00       31.19       18.90              24.95
# 4  00:30 - 01:00          -           -           -                  -
#
#   Buy Volume(MWh) Sell Volume(MWh) Volume(MWh)
# 0         3,117.5          2,670.9     2,894.2
# 1               -                -           -
# 2           337.0            311.5       324.2
# 3           198.4            195.9       197.1
# 4               -                -           -
